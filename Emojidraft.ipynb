# %% [markdown]
# # Libraries Needed

# %%
# !pip install -q fer
#Libraries needed 
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
#This is the model that we have it is called Facial Expression Recognizer...
from fer import FER
import os
# Out:
#      |████████████████████████████████| 812 kB 5.1 MB/s
#      |████████████████████████████████| 2.3 MB 58.5 MB/s

# %% [markdown]
# # Initiate Model

# %%
Model=FER(mtcnn=True)
Emotion_detector=Model.detect_emotions

# %%
face=Model.find_faces
face_coord=face(image)

# %%
image = cv2.imread('image.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
emoji = cv2.imread('emoji.png', cv2.IMREAD_UNCHANGED)

# %%
emoji.shape
# Out:
# (33, 29, 4)

# %%
emoji = cv2.cvtColor(emoji, cv2.COLOR_BGRA2RGBA)

# %%
plt.imshow(new_im)

# %%
detections=Emotion_detector(image)

# %%
# !pip install -q cvzone

# %%
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-90-95ceb2da45f2> in <module>()
#      15   size= (size[1],size[0])
#      16   emoji=cv2.resize(emoji,size)
# ---> 17   cropped_image = cv2.addWeighted(cropped_image,0.2,emoji,.7,0)
#      18   cropped_image= cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB)
#      19   plt.imshow(cropped_image)
#
# error: OpenCV(4.6.0) /io/opencv/modules/core/src/arithm.cpp:647: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'arithm_op'

# %%
import numpy as np
from PIL import Image
from typing import Sized
import cv2
import numpy as np 
import cvzone
for i in range(len(face_coord)):
  box=face_coord[i]
  left=face_coord[i][0]
  bottom=face_coord[i][1]
  right= left + face_coord[i][2]
  top= bottom+face_coord[i][3]
  cropped_image= image[bottom:top,left:right]
  size = cropped_image.shape
  size= (size[1],size[0])
  emoji=cv2.resize(emoji,size)
  cropped_image = cvzone.overlayPNG(cropped_image,emoji,(0,0))
  image[bottom:top,left:right]  = cropped_image

plt.imshow(image)
